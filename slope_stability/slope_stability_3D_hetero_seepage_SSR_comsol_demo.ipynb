% %% [markdown]
% # 3D Heterogeneous Seepage SSR (COMSOL Mesh)
%
% This notebook is a structured Jupyter version of `slope_stability_3D_hetero_seepage_SSR_comsol.m`.
%
% It performs:
% 1. Mesh and quadrature setup
% 2. Seepage solution
% 3. Mechanical assembly
% 4. SSR continuation solve
% 5. Inline visualization in notebook output

% %% [markdown]
% ## Notes Before Running
%
% - This workflow is computationally expensive (large 3D model).
% - It uses project package folders (`+ASSEMBLY`, `+MESH`, `+SEEPAGE`, `+VIZ`, etc.).
% - The default linear solver is `DFGMRES_HYPRE_BOOMERAMG`.
% - Inline plotting is enabled for Octave kernel using `%plot -f png`.

% %%
%plot -f png
close all; clearvars; clc;

% Load sparsersb for multithreaded sparse matrix-vector products
pkg load sparsersb;

% Configure toolkit for both GUI and headless Jupyter environments.
tks = available_graphics_toolkits();
if any(strcmp(tks, 'qt'))
    graphics_toolkit('qt');
    set(0, 'defaultfigurevisible', 'off');
elseif any(strcmp(tks, 'fltk'))
    graphics_toolkit('fltk');
    % fltk cannot print hidden figures in this environment.
    set(0, 'defaultfigurevisible', 'on');
end

% Ensure we are in the project folder where +package directories are visible.
if exist('ASSEMBLY.quadrature_volume_3D', 'file') ~= 2
    if isfolder('slope_stability')
        cd('slope_stability');
    end
end

fprintf('Working directory: %s\n', pwd);
fprintf('Graphics toolkit: %s\n', graphics_toolkit());
% Out:
% Working directory: /home/beremi/repos/slope_stability/slope_stability
% Graphics toolkit: qt

% %% [markdown]
% ## 1) Main Input Data
%
% Define FE type, material properties, geometry, and mesh density.

% %%
% elem_type - type of finite elements; available choices: 'P1', 'P2'
elem_type='P2';

% Davis_type - choice of Davis' approach; available choices: 'A','B','C'
Davis_type='B';

% Mechanical parameters per subdomain:
% [c0, phi, psi, young, poisson, gamma_sat, gamma_unsat]
mat_props = [15, 30,  0, 10000, 0.33, 19, 19;  % Cover layer
    15, 38,  0, 50000, 0.30, 22, 22;  % General foundation
    10, 35,  0, 50000, 0.30, 21, 21;  % Relatively weak foundation
    18, 32,  0, 20000, 0.33, 20, 20;  % General slope mass
    ];

% Hydraulic conductivity for each subdomain [m/s]
k = 1.0;

% Geometrical parameters
x1 = 15;  % length in front of slope
x2 = 10;  % slope length in x
x3 = 15;  % length behind slope
y1 = 10;  % height below slope
y2 = 10;  % slope height
z  = 5;   % length in z direction

% Mesh density parameter
N_h = 1;

% %% [markdown]
% ## 2) Reference Element Data and Mesh Load
%
% Build quadrature/basis data and load COMSOL mesh.

% %%
% quadrature points and weights for volume integration
[Xi, WF] = ASSEMBLY.quadrature_volume_3D(elem_type);

% local basis functions and their derivatives
[HatP, DHatP1, DHatP2, DHatP3] = ASSEMBLY.local_basis_volume_3D(elem_type, Xi);

% Mesh file
file_path = 'meshes/comsol_mesh.h5';
[coord, elem, surf, Q, material, triangle_labels] = MESH.load_mesh_P2(file_path, 1);

% Uncomment to reduce matrix bandwidth via Reverse Cuthill-McKee node reordering:
[coord, elem, surf, Q] = MESH.reorder_mesh(coord, elem, surf, Q);

% Mesh statistics
n_n = size(coord,2);
n_unknown = length(coord(Q));
n_e = size(elem,2);
n_q = length(WF);
n_int = n_e * n_q;

fprintf('\n');
fprintf('Mesh data:');
fprintf('  number of nodes =%d ', n_n);
fprintf('  number of unknowns =%d ', n_unknown);
fprintf('  number of elements =%d ', n_e);
fprintf('  number of integration points =%d ', n_int);
fprintf('\n');

% Homogeneous identifier for seepage helper call
material_identifier = zeros(1, n_e);
% Out:
%   Mesh reordering (symrcm): bandwidth 69441 -> 80266 (0.9x reduction)
%
% Mesh data:  number of nodes =80226   number of unknowns =231201   number of elements =55895   number of integration points =614845

% %% [markdown]
% ## 3) Seepage Problem
%
% Solve pore pressure and saturation state.

% %%
% Hydraulic conductivity at each integration point
conduct0 = SEEPAGE.heter_conduct(material_identifier, n_q, k);

% Specific weight of water [kPa]
grho = 9.81;

% Boundary conditions from COMSOL-labeled surfaces
[Q_w, pw_D] = MESH.seepage_boundary_3D_hetero_comsol(coord, surf, triangle_labels, grho);

% Solve seepage
[pw, grad_p, mater_sat] = SEEPAGE.seepage_problem_3D(
    coord, elem, Q_w, pw_D, grho, conduct0, HatP, DHatP1, DHatP2, DHatP3, WF);

% Integration-point saturation mask
mater_sat_ext = repmat(mater_sat, n_q, 1);
saturation = mater_sat_ext(:);
% Out:
% Newton solver converges: number of iteration=10 stopping criterion=4.530646e-17

% %% [markdown]
% ## 4) Mechanical Material Fields and Assembly
%
% Map material properties to integration points and assemble elastic stiffness and body-force vector.

% %%
fields = {'c0', 'phi', 'psi', 'young', 'poisson', 'gamma_sat', 'gamma_unsat'};
materials = cellfun(@(x) cell2struct(num2cell(x), fields, 2), num2cell(mat_props, 2), 'UniformOutput', false);

[c0, phi, psi, shear, bulk, lame, gamma] = ...
    ASSEMBLY.heterogenous_materials(material, saturation, n_q, materials);

% Elastic stiffness matrix + element-level derivative data (DPhi1/2/3)
[K_elast, B, WEIGHT, DPhi1_out, DPhi2_out, DPhi3_out] = ASSEMBLY.elastic_stiffness_matrix_3D(
    elem, coord, shear, bulk, DHatP1, DHatP2, DHatP3, WF);

% Volume forces at integration points: mechanical-only baseline
f_V_int = [zeros(1, n_int); -gamma; zeros(1, n_int)];
f_V = ASSEMBLY.vector_volume_3D(elem, coord, f_V_int, HatP, WEIGHT);

% %% [markdown]
% ## 5) Continuation, Newton, and Linear Solver Parameters

% %%
% Continuation parameters
lambda_init = 1.0;
d_lambda_init = 0.1;
d_lambda_min = 1e-5;
d_lambda_diff_scaled_min = 0.01;
omega_max_stop = 340700000;
step_max = 100;

% Newton parameters
it_newt_max = 50;
it_damp_max = 10;
tol = 1e-4;
r_min = 1e-4;

% Linear solver settings
agmg_folder = "agmg";
solver_type = 'DFGMRES_HYPRE_BOOMERAMG';

linear_solver_tolerance = 1e-1;
linear_solver_maxit = 100;
deflation_basis_tolerance = 1e-3;
linear_solver_printing = 1;

boomeramg_opts = struct('threads', 16, 'print_level', 0, ...
    'use_as_preconditioner', true);

linear_system_solver = LINEAR_SOLVERS.set_linear_solver(agmg_folder, solver_type, ...
    linear_solver_tolerance, linear_solver_maxit, deflation_basis_tolerance, ...
    linear_solver_printing, Q, coord, boomeramg_opts);

% Constitutive model object
n_strain = 6;
constitutive_matrix_builder = CONSTITUTIVE_PROBLEM.CONSTITUTIVE(
    B, c0, phi, psi, Davis_type, shear, bulk, lame, WEIGHT, n_strain, n_int, 3);

% Provide element geometry for fast element-level tangent assembly (208x speedup).
% This enables the C mex kernel instead of global B'*D*B sparse triple product.
constitutive_matrix_builder.set_element_data(elem, DPhi1_out, DPhi2_out, DPhi3_out);
% Out:
% Element data set: n_p=10, n_e=55895, n_q=11, mex=1

% %% [markdown]
% ## 6) Run SSR Continuation
%
% By default in this demonstration notebook:
% - `direct_on = 0`
% - `indirect_on = 1`

% %%
direct_on = 0;
indirect_on = 1;

if direct_on
    fprintf('\n Direct continuation method\n');
    tic;
    [U2, lambda_hist2, omega_hist2, Umax_hist2] = CONTINUATION.SSR_direct_continuation(...
        lambda_init, d_lambda_init, d_lambda_min, d_lambda_diff_scaled_min, step_max, ...
        it_newt_max, it_damp_max, tol, r_min, K_elast, Q, f_V, ...
        constitutive_matrix_builder, linear_system_solver.copy());
    time_run = toc;
    fprintf('Running_time = %f \n', time_run);

    figure; hold on; box on; grid on;
    plot(omega_hist2, lambda_hist2, '-o');
    title('Direct continuation method', 'Interpreter', 'latex');
    xlabel('variable - $\xi$', 'Interpreter', 'latex');
    ylabel('strength reduction factor - $\lambda$', 'Interpreter', 'latex');
end

if indirect_on
    fprintf('\n Indirect continuation method\n');
    tic;
    [U3, lambda_hist3, omega_hist3, Umax_hist3, stats] = CONTINUATION.SSR_indirect_continuation(...
        lambda_init, d_lambda_init, d_lambda_min, d_lambda_diff_scaled_min, step_max, ...
        omega_max_stop, it_newt_max, it_damp_max, tol, r_min, K_elast, Q, f_V, ...
        constitutive_matrix_builder, linear_system_solver.copy());
    time_run = toc;
    fprintf('Running_time = %f \n', time_run);

    figure; hold on; box on; grid on;
    plot(omega_hist3, lambda_hist3, '-o');
    title('Indirect continuation method', 'Interpreter', 'latex');
    xlabel('control variable - $\omega$', 'Interpreter', 'latex');
    ylabel('strength reduction factor - $\lambda$', 'Interpreter', 'latex');
end

if ~isempty(strfind(upper(char(solver_type)), 'BOOMERAMG'))
    LINEAR_SOLVERS.hypre_boomeramg_clear();
end
% Out:
%  Indirect continuation method
% Initialising K_r(Q,Q) sparse pattern ... done  (30.0 s, n_Q = 231201, nnz = 18763319)
% Building element scatter map ... done  (4.5 s, n_local_dof=30, map_size=402 MB)
%
%  Step = 1
% 3|  newton it=1  resid=1.00e+00  alpha=1.00  r=0.0001  step_time=1.44 s
% 2|  newton it=2  resid=5.26e-02  alpha=1.00  r=0.0001  step_time=1.37 s
% 3|  newton it=3  resid=5.08e-03  alpha=1.00  r=0.0001  step_time=1.44 s
% 3|  newton it=4  resid=4.44e-04  alpha=1.00  r=0.0001  step_time=1.46 s
% Newton method converges: iteration = 5, stopping criterion = 6.362793e-05
%    lambda_init = 1, d_lambda_init = 0.1, omega_init = 6013302.5825
%
%  Step = 2
% 3|  newton it=1  resid=5.09e-03  alpha=0.97  r=0.0001  step_time=2.62 s
% 2|  newton it=2  resid=2.56e-03  alpha=1.00  r=0.0001  step_time=1.41 s
% 3|  newton it=3  resid=1.55e-04  alpha=1.00  r=0.0001  step_time=1.46 s
% Newton method converges: iteration = 4, stopping criterion = 8.265284e-06
%    lambda1 = 1, lambda2 = 1.1, d_lambda = 0.1, omega1 = 6013302.5825, omega2 = 6013371.839, d_omega = 69.2565
%
%  Step = 3
%
% 3|3|  newton_ind_SSR it=1  resid=5.63e-03  alpha=1.00  r=0.0001  step_time=1.78 s
% 2|2|  newton_ind_SSR it=2  resid=2.01e-03  alpha=1.00  r=0.0001  step_time=1.64 s
% 1|2|  newton_ind_SSR it=3  resid=3.23e-04  alpha=1.00  r=0.0001  step_time=1.60 s
% Newton method converges: iteration = 4, rel. resid = 2.893534e-05
%    lambda = 1.1272, d_lambda = 0.027217, d_lambda_diff_scaled = 0.054434, omega = 6013441.0956, d_omega = 69.2565, U_max = 0.72836
%
%  Step = 4
%
% 2|2|  newton_ind_SSR it=1  resid=7.08e-03  alpha=1.00  r=0.0001  step_time=1.68 s
% 2|2|  newton_ind_SSR it=2  resid=2.97e-03  alpha=1.00  r=0.0001  step_time=1.67 s
% 1|2|  newton_ind_SSR it=3  resid=5.54e-04  alpha=1.00  r=0.0001  step_time=1.61 s
% Newton method converges: iteration = 4, rel. resid = 7.886204e-05
%    lambda = 1.163, d_lambda = 0.035824, d_lambda_diff_scaled = 0.071649, omega = 6013579.6086, d_omega = 138.513, U_max = 0.72839
%
%  Step = 5
%
% 1|0|  newton_ind_SSR it=1  resid=4.72e-03  alpha=1.00  r=0.0001  step_time=1.47 s
% 2|2|  newton_ind_SSR it=2  resid=1.82e-03  alpha=1.00  r=0.0001  step_time=1.65 s
% 1|2|  newton_ind_SSR it=3  resid=3.46e-04  alpha=1.00  r=0.0001  step_time=1.62 s
% Newton method converges: iteration = 4, rel. resid = 3.468355e-05
%    lambda = 1.1891, d_lambda = 0.02605, d_lambda_diff_scaled = 0.07815, omega = 6013718.1216, d_omega = 138.513, U_max = 0.72844
%
%  Step = 6
%
% 1|0|  newton_ind_SSR it=1  resid=7.07e-03  alpha=1.00  r=0.0001  step_time=1.50 s
% 2|3|  newton_ind_SSR it=2  resid=3.24e-03  alpha=1.00  r=0.0001  step_time=1.73 s
% 1|2|  newton_ind_SSR it=3  resid=1.02e-03  alpha=1.00  r=0.0001  step_time=1.63 s
% Newton method converges: iteration = 4, rel. resid = 6.997897e-05
%    lambda = 1.228, d_lambda = 0.038945, d_lambda_diff_scaled = 0.097362, omega = 6013995.1477, d_omega = 277.0261, U_max = 0.7286
%
%  Step = 7
%
% 2|1|  newton_ind_SSR it=1  resid=5.24e-03  alpha=1.00  r=0.0001  step_time=1.64 s
% 2|2|  newton_ind_SSR it=2  resid=2.40e-03  alpha=1.00  r=0.0001  step_time=1.68 s
% 1|2|  newton_ind_SSR it=3  resid=5.11e-04  alpha=1.00  r=0.0001  step_time=1.63 s
% Newton method converges: iteration = 4, rel. resid = 4.749041e-05
%    lambda = 1.2571, d_lambda = 0.029086, d_lambda_diff_scaled = 0.1018, omega = 6014272.1738, d_omega = 277.0261, U_max = 0.7288
%
%  Step = 8
%
% 2|1|  newton_ind_SSR it=1  resid=8.53e-03  alpha=1.00  r=0.0001  step_time=1.65 s
% 3|3|  newton_ind_SSR it=2  resid=4.17e-03  alpha=1.00  r=0.0001  step_time=1.80 s
% 2|2|  newton_ind_SSR it=3  resid=2.07e-03  alpha=1.00  r=0.0001  step_time=1.74 s
% 1|3|  newton_ind_SSR it=4  resid=1.22e-04  alpha=1.00  r=0.0001  step_time=1.73 s
% Newton method converges: iteration = 5, rel. resid = 8.049430e-06
%    lambda = 1.2966, d_lambda = 0.039446, d_lambda_diff_scaled = 0.10848, omega = 6014826.226, d_omega = 554.0522, U_max = 0.72906
%
%  Step = 9
%
% 2|1|  newton_ind_SSR it=1  resid=6.29e-03  alpha=1.00  r=0.0001  step_time=1.65 s
% 2|2|  newton_ind_SSR it=2  resid=2.62e-03  alpha=1.00  r=0.0001  step_time=1.69 s
% 1|2|  newton_ind_SSR it=3  resid=5.03e-04  alpha=1.00  r=0.0001  step_time=1.66 s
% Newton method converges: iteration = 4, rel. resid = 5.879366e-05
%    lambda = 1.3224, d_lambda = 0.025836, d_lambda_diff_scaled = 0.096884, omega = 6015380.2781, d_omega = 554.0522, U_max = 0.72913
%
%  Step = 10
%
% 2|1|  newton_ind_SSR it=1  resid=9.74e-03  alpha=1.00  r=0.0001  step_time=1.67 s
% 2|3|  newton_ind_SSR it=2  resid=3.98e-03  alpha=1.00  r=0.0001  step_time=1.76 s
% 2|3|  newton_ind_SSR it=3  resid=7.83e-04  alpha=1.00  r=0.0001  step_time=1.79 s
% Newton method converges: iteration = 4, rel. resid = 7.851319e-05
%    lambda = 1.3577, d_lambda = 0.035262, d_lambda_diff_scaled = 0.10138, omega = 6016488.3825, d_omega = 1108.1043, U_max = 0.72907
%
%  Step = 11
%
% 2|1|  newton_ind_SSR it=1  resid=7.01e-03  alpha=1.00  r=0.0001  step_time=1.67 s
% 2|3|  newton_ind_SSR it=2  resid=2.90e-03  alpha=1.00  r=0.0001  step_time=1.79 s
% 1|3|  newton_ind_SSR it=3  resid=5.79e-04  alpha=1.00  r=0.0001  step_time=1.73 s
% Newton method converges: iteration = 4, rel. resid = 5.788168e-05
%    lambda = 1.3836, d_lambda = 0.025964, d_lambda_diff_scaled = 0.10061, omega = 6017596.4868, d_omega = 1108.1043, U_max = 0.72898
%
%  Step = 12
%
% 2|1|  newton_ind_SSR it=1  resid=1.13e-02  alpha=1.00  r=0.0001  step_time=1.68 s
% 3|3|  newton_ind_SSR it=2  resid=4.96e-03  alpha=1.00  r=0.0001  step_time=1.86 s
% 2|3|  newton_ind_SSR it=3  resid=1.64e-03  alpha=1.00  r=0.0001  step_time=1.80 s
% 1|6|  newton_ind_SSR it=4  resid=1.74e-04  alpha=1.00  r=0.0001  step_time=1.95 s
% Newton method converges: iteration = 5, rel. resid = 2.258816e-05
%    lambda = 1.4226, d_lambda = 0.038932, d_lambda_diff_scaled = 0.11436, omega = 6019812.6955, d_omega = 2216.2087, U_max = 0.72907
%
%  Step = 13
%
% 2|1|  newton_ind_SSR it=1  resid=8.36e-03  alpha=1.00  r=0.0001  step_time=1.68 s
% 3|3|  newton_ind_SSR it=2  resid=3.98e-03  alpha=1.00  r=0.0001  step_time=1.85 s
% 1|3|  newton_ind_SSR it=3  resid=8.41e-04  alpha=1.00  r=0.0001  step_time=1.76 s
% 1|6|  newton_ind_SSR it=4  resid=1.25e-04  alpha=1.00  r=0.0001  step_time=1.95 s
% Newton method converges: iteration = 5, rel. resid = 1.525672e-05
%    lambda = 1.4516, d_lambda = 0.029051, d_lambda_diff_scaled = 0.11439, omega = 6022028.9041, d_omega = 2216.2087, U_max = 0.72947
%
%  Step = 14
%
% 3|1|  newton_ind_SSR it=1  resid=1.36e-02  alpha=1.00  r=0.0001  step_time=1.77 s
% 3|3|  newton_ind_SSR it=2  resid=6.09e-03  alpha=1.00  r=0.0001  step_time=1.89 s
% 2|3|  newton_ind_SSR it=3  resid=1.67e-03  alpha=1.00  r=0.0001  step_time=1.83 s
% 1|7|  newton_ind_SSR it=4  resid=2.28e-04  alpha=1.00  r=0.0001  step_time=2.05 s
% Newton method converges: iteration = 5, rel. resid = 2.667385e-05
%    lambda = 1.494, d_lambda = 0.042392, d_lambda_diff_scaled = 0.12585, omega = 6026461.3215, d_omega = 4432.4173, U_max = 0.73143
%
%  Step = 15
%
% 3|1|  newton_ind_SSR it=1  resid=1.06e-02  alpha=1.00  r=0.0001  step_time=1.75 s
% 2|3|  newton_ind_SSR it=2  resid=3.86e-03  alpha=1.00  r=0.0001  step_time=1.83 s
% 1|3|  newton_ind_SSR it=3  resid=8.08e-04  alpha=1.00  r=0.0001  step_time=1.80 s
% 1|9|  newton_ind_SSR it=4  resid=1.19e-04  alpha=1.00  r=0.0001  step_time=2.18 s
% Newton method converges: iteration = 5, rel. resid = 1.145480e-05
%    lambda = 1.5249, d_lambda = 0.030888, d_lambda_diff_scaled = 0.12259, omega = 6030893.7388, d_omega = 4432.4173, U_max = 0.73479
%
%  Step = 16
%
% 3|2|  newton_ind_SSR it=1  resid=1.67e-02  alpha=1.00  r=0.0001  step_time=1.85 s
% 3|3|  newton_ind_SSR it=2  resid=5.51e-03  alpha=1.00  r=0.0001  step_time=1.91 s
% 3|4|  newton_ind_SSR it=3  resid=1.93e-03  alpha=1.00  r=0.0001  step_time=1.97 s
% 2|8|  newton_ind_SSR it=4  resid=2.74e-04  alpha=1.00  r=0.0001  step_time=2.23 s
% Newton method converges: iteration = 5, rel. resid = 3.392757e-05
%    lambda = 1.5658, d_lambda = 0.040907, d_lambda_diff_scaled = 0.12208, omega = 6039758.5735, d_omega = 8864.8347, U_max = 0.74562
%
%  Step = 17
%
% 6|2|  newton_ind_SSR it=1  resid=1.18e-02  alpha=1.00  r=0.0001  step_time=2.07 s
% 4|5|  newton_ind_SSR it=2  resid=3.57e-03  alpha=0.50  r=0.0001  step_time=2.28 s
% 3|4|  newton_ind_SSR it=3  resid=2.28e-03  alpha=1.00  r=0.0001  step_time=2.01 s
% 3|7|  newton_ind_SSR it=4  resid=9.89e-04  alpha=1.00  r=0.0001  step_time=2.23 s
% 2|12|  newton_ind_SSR it=5  resid=1.40e-04  alpha=1.00  r=0.0001  step_time=2.56 s
% Newton method converges: iteration = 6, rel. resid = 5.140107e-05
%    lambda = 1.5824, d_lambda = 0.016645, d_lambda_diff_scaled = 0.066321, omega = 6048623.4082, d_omega = 8864.8347, U_max = 0.8147
%
%  Step = 18
%
% 6|2|  newton_ind_SSR it=1  resid=1.38e-02  alpha=1.00  r=0.0001  step_time=2.07 s
% 4|5|  newton_ind_SSR it=2  resid=3.96e-03  alpha=1.00  r=0.0001  step_time=2.12 s
% 3|4|  newton_ind_SSR it=3  resid=3.54e-03  alpha=1.00  r=0.0001  step_time=2.02 s
% 2|5|  newton_ind_SSR it=4  resid=2.25e-03  alpha=0.12  r=0.0001  step_time=2.61 s
% 1|4|  newton_ind_SSR it=5  resid=2.00e-03  alpha=1.00  r=0.0001  step_time=1.92 s
% 2|4|  newton_ind_SSR it=6  resid=1.57e-03  alpha=1.00  r=0.0001  step_time=2.01 s
% 1|3|  newton_ind_SSR it=7  resid=1.29e-03  alpha=0.50  r=0.0001  step_time=2.09 s
% 1|3|  newton_ind_SSR it=8  resid=9.17e-04  alpha=1.00  r=0.0001  step_time=1.96 s
% 1|13|  newton_ind_SSR it=9  resid=1.24e-04  alpha=1.00  r=0.0001  step_time=2.72 s
% Newton method converges: iteration = 10, rel. resid = 2.115410e-05
%    lambda = 1.5943, d_lambda = 0.011903, d_lambda_diff_scaled = 0.035616, omega = 6066353.0775, d_omega = 17729.6693, U_max = 1.0494
%
%  Step = 19
%
% 5|1|  newton_ind_SSR it=1  resid=1.68e-02  alpha=1.00  r=0.0001  step_time=1.93 s
% 4|6|  newton_ind_SSR it=2  resid=3.14e-03  alpha=1.00  r=0.0001  step_time=2.23 s
% 2|8|  newton_ind_SSR it=3  resid=9.52e-04  alpha=0.50  r=0.0001  step_time=2.41 s
% 1|6|  newton_ind_SSR it=4  resid=7.94e-04  alpha=1.00  r=0.0001  step_time=2.10 s
% 1|6|  newton_ind_SSR it=5  resid=4.94e-04  alpha=0.50  r=0.0001  step_time=2.28 s
% 1|5|  newton_ind_SSR it=6  resid=4.60e-04  alpha=1.00  r=0.0001  step_time=2.05 s
% 1|10|  newton_ind_SSR it=7  resid=1.40e-04  alpha=1.00  r=0.0001  step_time=2.43 s
% Newton method converges: iteration = 8, rel. resid = 1.782914e-05
%    lambda = 1.604, d_lambda = 0.009652, d_lambda_diff_scaled = 0.024092, omega = 6101812.4162, d_omega = 35459.3387, U_max = 1.6118
%
%  Step = 20
%
% 3|1|  newton_ind_SSR it=1  resid=2.37e-02  alpha=1.00  r=0.0001  step_time=1.82 s
% 2|6|  newton_ind_SSR it=2  resid=4.26e-03  alpha=1.00  r=0.0001  step_time=2.09 s
% 2|7|  newton_ind_SSR it=3  resid=1.15e-03  alpha=1.00  r=0.0001  step_time=2.22 s
% 1|9|  newton_ind_SSR it=4  resid=4.40e-04  alpha=0.50  r=0.0001  step_time=2.48 s
% 1|7|  newton_ind_SSR it=5  resid=3.36e-04  alpha=1.00  r=0.0001  step_time=2.18 s
% 0|14|  newton_ind_SSR it=6  resid=1.13e-04  alpha=0.25  r=0.0001  step_time=2.97 s
% Newton method converges: iteration = 7, rel. resid = 8.630721e-05
%    lambda = 1.6131, d_lambda = 0.009141, d_lambda_diff_scaled = 0.020549, omega = 6172731.0936, d_omega = 70918.6774, U_max = 2.8753
%
%  Step = 21
%
% 2|2|  newton_ind_SSR it=1  resid=1.47e-02  alpha=1.00  r=0.0001  step_time=1.86 s
% 1|6|  newton_ind_SSR it=2  resid=2.01e-03  alpha=1.00  r=0.0001  step_time=2.08 s
% 1|10|  newton_ind_SSR it=3  resid=4.49e-04  alpha=1.00  r=0.0001  step_time=2.37 s
% 1|18|  newton_ind_SSR it=4  resid=1.27e-04  alpha=0.50  r=0.0001  step_time=3.11 s
% Newton method converges: iteration = 5, rel. resid = 9.823333e-05
%    lambda = 1.6184, d_lambda = 0.0052504, d_lambda_diff_scaled = 0.017054, omega = 6243649.771, d_omega = 70918.6774, U_max = 4.3293
%
%  Step = 22
%
% 2|2|  newton_ind_SSR it=1  resid=2.34e-02  alpha=1.00  r=0.0001  step_time=1.86 s
% 1|6|  newton_ind_SSR it=2  resid=3.35e-03  alpha=1.00  r=0.0001  step_time=2.07 s
% 1|4|  newton_ind_SSR it=3  resid=2.55e-03  alpha=1.00  r=0.0001  step_time=1.96 s
% 0|10|  newton_ind_SSR it=4  resid=6.67e-04  alpha=0.50  r=0.0001  step_time=2.47 s
% 0|9|  newton_ind_SSR it=5  resid=4.45e-04  alpha=1.00  r=0.0001  step_time=2.33 s
% 0|19|  newton_ind_SSR it=6  resid=2.01e-04  alpha=0.25  r=0.0001  step_time=3.42 s
% 0|15|  newton_ind_SSR it=7  resid=1.75e-04  alpha=0.25  r=0.0001  step_time=3.09 s
% 0|18|  newton_ind_SSR it=8  resid=1.28e-04  alpha=1.00  r=0.0001  step_time=3.02 s
% Newton method converges: iteration = 9, rel. resid = 2.486661e-05
%    lambda = 1.6249, d_lambda = 0.0065212, d_lambda_diff_scaled = 0.017112, omega = 6385487.1257, d_omega = 141837.3548, U_max = 7.2192
%
%  Step = 23
%
% 2|2|  newton_ind_SSR it=1  resid=1.82e-02  alpha=1.00  r=0.0001  step_time=1.87 s
% 1|7|  newton_ind_SSR it=2  resid=2.37e-03  alpha=1.00  r=0.0001  step_time=2.19 s
% 1|6|  newton_ind_SSR it=3  resid=1.16e-03  alpha=1.00  r=0.0001  step_time=2.12 s
% 0|15|  newton_ind_SSR it=4  resid=2.60e-04  alpha=1.00  r=0.0001  step_time=2.69 s
% 0|16|  newton_ind_SSR it=5  resid=1.79e-04  alpha=1.00  r=0.0001  step_time=2.77 s
% 0|22|  newton_ind_SSR it=6  resid=1.12e-04  alpha=1.00  r=0.0001  step_time=3.46 s
% Newton method converges: iteration = 7, rel. resid = 9.817302e-05
%    lambda = 1.6291, d_lambda = 0.0041919, d_lambda_diff_scaled = 0.015191, omega = 6527324.4805, d_omega = 141837.3548, U_max = 10.0846
%
%  Step = 24
%
% 2|3|  newton_ind_SSR it=1  resid=3.33e-02  alpha=1.00  r=0.0001  step_time=2.01 s
% 1|6|  newton_ind_SSR it=2  resid=5.65e-03  alpha=1.00  r=0.0001  step_time=2.14 s
% 0|8|  newton_ind_SSR it=3  resid=1.53e-03  alpha=1.00  r=0.0001  step_time=2.22 s
% 0|8|  newton_ind_SSR it=4  resid=8.01e-04  alpha=1.00  r=0.0001  step_time=2.26 s
% 0|9|  newton_ind_SSR it=5  resid=5.38e-04  alpha=0.12  r=0.0001  step_time=2.86 s
% 0|6|  newton_ind_SSR it=6  resid=5.17e-04  alpha=0.50  r=0.0001  step_time=2.38 s
% 0|6|  newton_ind_SSR it=7  resid=4.24e-04  alpha=1.00  r=0.0001  step_time=2.29 s
% 0|22|  newton_ind_SSR it=8  resid=1.26e-04  alpha=1.00  r=0.0001  step_time=3.56 s
% 0|15|  newton_ind_SSR it=9  resid=1.13e-04  alpha=1.00  r=0.0001  step_time=2.99 s
% Newton method converges: iteration = 10, rel. resid = 4.422717e-05
%    lambda = 1.6345, d_lambda = 0.0054367, d_lambda_diff_scaled = 0.015288, omega = 6810999.19, d_omega = 283674.7095, U_max = 16.0216
%
%  Step = 25
%
% 2|3|  newton_ind_SSR it=1  resid=2.81e-02  alpha=1.00  r=0.0001  step_time=2.07 s
% 1|6|  newton_ind_SSR it=2  resid=4.74e-03  alpha=1.00  r=0.0001  step_time=2.23 s
% 0|7|  newton_ind_SSR it=3  resid=1.97e-03  alpha=0.25  r=0.0001  step_time=2.56 s
% 0|5|  newton_ind_SSR it=4  resid=1.97e-03  alpha=1.00  r=0.0001  step_time=2.03 s
% 0|10|  newton_ind_SSR it=5  resid=5.89e-04  alpha=1.00  r=0.0001  step_time=2.45 s
% 0|8|  newton_ind_SSR it=6  resid=4.68e-04  alpha=0.50  r=0.0001  step_time=2.52 s
% 0|8|  newton_ind_SSR it=7  resid=3.40e-04  alpha=1.00  r=0.0001  step_time=2.39 s
% 0|20|  newton_ind_SSR it=8  resid=1.15e-04  alpha=0.12  r=0.0001  step_time=3.91 s
% 0|15|  newton_ind_SSR it=9  resid=1.01e-04  alpha=1.00  r=0.0001  step_time=3.02 s
% Newton method converges: iteration = 10, rel. resid = 3.983044e-05
%    lambda = 1.6381, d_lambda = 0.0035425, d_lambda_diff_scaled = 0.013504, omega = 7094673.8995, d_omega = 283674.7095, U_max = 22.0217
%
%  Step = 26
%
% 2|3|  newton_ind_SSR it=1  resid=5.32e-02  alpha=1.00  r=0.0001  step_time=2.00 s
% 1|5|  newton_ind_SSR it=2  resid=1.05e-02  alpha=1.00  r=0.0001  step_time=2.13 s
% 0|9|  newton_ind_SSR it=3  resid=3.13e-03  alpha=0.25  r=0.0001  step_time=2.73 s
% 0|6|  newton_ind_SSR it=4  resid=2.60e-03  alpha=1.00  r=0.0001  step_time=2.19 s
% 0|10|  newton_ind_SSR it=5  resid=1.09e-03  alpha=0.50  r=0.0001  step_time=2.68 s
% 0|8|  newton_ind_SSR it=6  resid=9.80e-04  alpha=0.12  r=0.0001  step_time=2.86 s
% 0|6|  newton_ind_SSR it=7  resid=9.38e-04  alpha=1.00  r=0.0001  step_time=2.20 s
% 0|17|  newton_ind_SSR it=8  resid=2.98e-04  alpha=0.12  r=0.0001  step_time=3.66 s
% 0|12|  newton_ind_SSR it=9  resid=2.86e-04  alpha=0.50  r=0.0001  step_time=2.96 s
% 0|10|  newton_ind_SSR it=10  resid=2.81e-04  alpha=1.00  r=0.0001  step_time=2.66 s
% Newton method converges: iteration = 11, rel. resid = 9.475347e-05
%    lambda = 1.6426, d_lambda = 0.0045493, d_lambda_diff_scaled = 0.01322, omega = 7662023.3185, d_omega = 567349.419, U_max = 34.1442
%
%  Step = 27
%
% 3|3|  newton_ind_SSR it=1  resid=4.55e-02  alpha=1.00  r=0.0001  step_time=2.29 s
% 0|6|  newton_ind_SSR it=2  resid=7.43e-03  alpha=1.00  r=0.0001  step_time=2.10 s
% 0|8|  newton_ind_SSR it=3  resid=3.15e-03  alpha=0.50  r=0.0001  step_time=2.42 s
% 0|8|  newton_ind_SSR it=4  resid=1.88e-03  alpha=1.00  r=0.0001  step_time=2.33 s
% 0|9|  newton_ind_SSR it=5  resid=1.18e-03  alpha=0.25  r=0.0001  step_time=2.74 s
% 0|8|  newton_ind_SSR it=6  resid=9.43e-04  alpha=0.50  r=0.0001  step_time=2.58 s
% 0|8|  newton_ind_SSR it=7  resid=7.18e-04  alpha=1.00  r=0.0001  step_time=2.42 s
% 0|7|  newton_ind_SSR it=8  resid=6.69e-04  alpha=0.50  r=0.0001  step_time=2.64 s
% 0|8|  newton_ind_SSR it=9  resid=4.50e-04  alpha=1.00  r=0.0001  step_time=2.49 s
% 0|21|  newton_ind_SSR it=10  resid=1.51e-04  alpha=0.25  r=0.0001  step_time=3.96 s
% 0|14|  newton_ind_SSR it=11  resid=1.48e-04  alpha=1.00  r=0.0001  step_time=2.98 s
% Newton method converges: iteration = 12, rel. resid = 4.755562e-05
%    lambda = 1.6455, d_lambda = 0.0029097, d_lambda_diff_scaled = 0.011365, omega = 8229372.7376, d_omega = 567349.419, U_max = 46.3334
%
%  Step = 28
%
% 3|3|  newton_ind_SSR it=1  resid=8.47e-02  alpha=1.00  r=0.0001  step_time=2.23 s
% 0|5|  newton_ind_SSR it=2  resid=1.94e-02  alpha=1.00  r=0.0001  step_time=2.10 s
% 0|9|  newton_ind_SSR it=3  resid=6.03e-03  alpha=0.25  r=0.0001  step_time=2.79 s
% 0|6|  newton_ind_SSR it=4  resid=5.38e-03  alpha=1.00  r=0.0001  step_time=2.23 s
% 0|9|  newton_ind_SSR it=5  resid=2.78e-03  alpha=0.12  r=0.0001  step_time=3.04 s
% 0|6|  newton_ind_SSR it=6  resid=2.68e-03  alpha=1.00  r=0.0001  step_time=2.27 s
% 0|8|  newton_ind_SSR it=7  resid=1.99e-03  alpha=0.12  r=0.0001  step_time=2.91 s
% 0|6|  newton_ind_SSR it=8  resid=1.96e-03  alpha=0.50  r=0.0001  step_time=2.51 s
% 0|8|  newton_ind_SSR it=9  resid=1.34e-03  alpha=0.12  r=0.0001  step_time=2.99 s
% 0|6|  newton_ind_SSR it=10  resid=1.25e-03  alpha=1.00  r=0.0001  step_time=2.29 s
% 0|24|  newton_ind_SSR it=11  resid=4.59e-04  alpha=0.12  r=0.0001  step_time=4.47 s
% 0|19|  newton_ind_SSR it=12  resid=4.08e-04  alpha=0.50  r=0.0001  step_time=3.63 s

% %% [markdown]
% ## Newton Profiler Summary
%
% Display accumulated timing from `newton_ind_SSR` across all continuation attempts:
% - **Top-level** breakdown sorted by total time (descending)
% - **Sub-profiles** for `build_F_and_DS_all`, `damping_ALG5`, and `dfgmres_solver` with per-line timing and hit counts

% %%
if indirect_on && exist('stats', 'var') && isfield(stats, 'newton_timing')
    nt = stats.newton_timing;

    %% --- Top-level timing table (existing fields only) ---
    top_fields = {'build_F_and_DS', 'solve_V', 'A_orthogonalize', 'damping', ...
                  'setup_preconditioner', 'build_F_eps', 'solve_W', ...
                  'K_r_assembly', 'sparsersb_build', ...
                  'expand_deflation_W', 'expand_deflation_V'};
    top_labels = top_fields(isfield(nt, top_fields));
    top_times  = cellfun(@(f) nt.(f), top_labels);
    total      = sum(top_times);

    [top_times, idx] = sort(top_times, 'descend');
    top_labels = top_labels(idx);
    pcts       = 100 * top_times / total;

    desc_map = struct( ...
        'build_F_and_DS',      'build_F_and_DS_all     (constitutive F + DS)', ...
        'solve_V',             'linear_solver.solve     (V solve)',           ...
        'A_orthogonalize',     'linear_solver.A_orthogonalize',              ...
        'damping',             'NEWTON.damping_ALG5     (line search)',       ...
        'setup_preconditioner','setup/update preconditioner (HYPRE IJV)',     ...
        'build_F_eps',         'build_F_all             (F_eps for diff)',    ...
        'solve_W',             'linear_solver.solve     (W solve)',           ...
        'K_r_assembly',        'K_r sparsersb assembly  (BtDB prebuilt)',    ...
        'expand_deflation_W',  'expand_deflation_basis  (W)',                ...
        'expand_deflation_V',  'expand_deflation_basis  (V)');

    fprintf('\n============================================================\n');
    fprintf('  Newton Profiler  (newton_ind_SSR accumulated)\n');
    fprintf('============================================================\n');
    fprintf('  %-6s  %-8s  %s\n', 'Time', '  %', 'Operation');
    fprintf('  %-6s  %-8s  %s\n', '------', '------', '------------------------------');
    for k = 1:numel(top_labels)
        lbl = top_labels{k};
        if isfield(desc_map, lbl)
            desc = desc_map.(lbl);
        else
            desc = lbl;
        end
        fprintf('  %6.1fs  %5.1f%%   %s\n', top_times(k), pcts(k), desc);
    end
    fprintf('  %-6s  %-8s  %s\n', '------', '------', '------------------------------');
    fprintf('  %6.1fs  %5.1f%%   %s\n', total, 100.0, 'TOTAL');
    fprintf('============================================================\n');

    %% --- Sub-profiling: build_F_and_DS_all breakdown ---
    if isfield(nt, 'build_F_DS__n_calls')
        fprintf('\n  Sub-profile: build_F_and_DS_all  (%d calls)\n', nt.build_F_DS__n_calls);
        fprintf('  %-6s  %-8s  %s\n', '------', '------', '------------------------------');
        sub_items = { ...
            nt.build_F_DS__reduction,      'reduction(lambda)'; ...
            nt.build_F_DS__stress_tangent, 'constitutive_problem_stress_tangent(U)'; ...
            nt.build_F_DS__build_F,        'build_F()'};
        sub_total = nt.build_F_and_DS;
        for k = 1:size(sub_items, 1)
            fprintf('  %6.2fs  %5.1f%%   %s\n', sub_items{k,1}, ...
                100 * sub_items{k,1} / max(sub_total, 1e-12), sub_items{k,2});
        end
    end

    %% --- Sub-profiling: damping_ALG5 breakdown ---
    if isfield(nt, 'damping__n_calls')
        fprintf('\n  Sub-profile: damping_ALG5  (%d calls, %d damp iters total)\n', ...
            nt.damping__n_calls, nt.damping__n_iters);
        fprintf('  %-6s  %-8s  %s\n', '------', '------', '------------------------------');
        sub_items = { ...
            nt.damping__build_F, 'build_F_all  (constitutive evaluation)'; ...
            nt.damping__norm,    'norm(F(Q)-f(Q))  (residual check)'};
        sub_total = nt.damping;
        for k = 1:size(sub_items, 1)
            fprintf('  %6.2fs  %5.1f%%   %s\n', sub_items{k,1}, ...
                100 * sub_items{k,1} / max(sub_total, 1e-12), sub_items{k,2});
        end
    end

    %% --- Sub-profiling: dfgmres_solver breakdown (V+W combined) ---
    if isfield(nt, 'solve__n_calls')
        fprintf('\n  Sub-profile: dfgmres_solver  (%d calls, %d GMRES iters, %d matvecs, %d prec applies)\n', ...
            nt.solve__n_calls, nt.solve__n_gmres_iters, ...
            nt.solve__n_matvecs, nt.solve__n_prec_applies);
        fprintf('  %-6s  %-8s  %s\n', '------', '------', '------------------------------');
        sub_items = { ...
            nt.solve__precond,     'M(v)  preconditioner apply'; ...
            nt.solve__matvec,      'A*w   matrix-vector product'; ...
            nt.solve__project,     'Proj(w) deflation projection'; ...
            nt.solve__ortho,       'Arnoldi orthogonalisation'; ...
            nt.solve__leastsq,     'least-squares + residual check'; ...
            nt.solve__init,        'init (coarse solve + r0)'; ...
            nt.solve__reconstruct, 'solution reconstruction'};
        sub_total = nt.solve_V + nt.solve_W;
        for k = 1:size(sub_items, 1)
            fprintf('  %6.2fs  %5.1f%%   %s\n', sub_items{k,1}, ...
                100 * sub_items{k,1} / max(sub_total, 1e-12), sub_items{k,2});
        end
    end

    fprintf('============================================================\n');
else
    fprintf('No Newton timing data available.\n');
end
% Out:
% ============================================================
%   Newton Profiler  (newton_ind_SSR accumulated)
% ============================================================
%   Time      %       Operation
%   ------  ------    ------------------------------
%     92.4s   24.9%   linear_solver.solve     (V solve)
%     66.0s   17.8%   setup/update preconditioner (HYPRE IJV)
%     43.4s   11.7%   NEWTON.damping_ALG5     (line search)
%     36.0s    9.7%   build_F_and_DS_all     (constitutive F + DS)
%     33.1s    8.9%   K_r sparsersb assembly  (BtDB prebuilt)
%     27.8s    7.5%   build_F_all             (F_eps for diff)
%     27.0s    7.3%   linear_solver.A_orthogonalize
%     26.2s    7.1%   sparsersb_build
%     17.3s    4.7%   linear_solver.solve     (W solve)
%      0.8s    0.2%   expand_deflation_basis  (W)
%      0.8s    0.2%   expand_deflation_basis  (V)
%   ------  ------    ------------------------------
%    371.0s  100.0%   TOTAL
% ============================================================
%
%   Sub-profile: build_F_and_DS_all  (189 calls)
%   ------  ------    ------------------------------
%     9.39s   26.1%   reduction(lambda)
%    19.40s   53.9%   constitutive_problem_stress_tangent(U)
%     7.21s   20.0%   build_F()
%
%   Sub-profile: damping_ALG5  (162 calls, 244 damp iters total)
%   ------  ------    ------------------------------
%    41.95s   96.7%   build_F_all  (constitutive evaluation)
%     1.37s    3.2%   norm(F(Q)-f(Q))  (residual check)
%
%   Sub-profile: dfgmres_solver  (324 calls, 1391 GMRES iters, 3106 matvecs, 1391 prec applies)
%   ------  ------    ------------------------------
%    68.39s   62.3%   M(v)  preconditioner apply
%     3.53s    3.2%   A*w   matrix-vector product
%    19.90s   18.1%   Proj(w) deflation projection
%     2.49s    2.3%   Arnoldi orthogonalisation
%     0.13s    0.1%   least-squares + residual check
%    13.68s   12.5%   init (coarse solve + r0)
%     0.10s    0.1%   solution reconstruction
% ============================================================

% %%
linear_system_solver.iteration_collector.iterations
% Out:
% ans =
% {
%   [1,1] = {}(0x0)
%   [1,2] = {}(0x0)
%   [1,3] =
%   {
%     [1,1] = 3
%     [1,2] = 2
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 3
%     [1,6] = 2
%     [1,7] = 3
%   }
%
%   [1,4] =
%   {
%     [1,1] = 3
%     [1,2] = 3
%     [1,3] = 2
%     [1,4] = 2
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,5] =
%   {
%     [1,1] = 2
%     [1,2] = 2
%     [1,3] = 2
%     [1,4] = 2
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,6] =
%   {
%     [1,1] = 1
%     [1,2] = 0
%     [1,3] = 2
%     [1,4] = 2
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,7] =
%   {
%     [1,1] = 1
%     [1,2] = 0
%     [1,3] = 2
%     [1,4] = 3
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,8] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 2
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,9] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 2
%     [1,6] = 2
%     [1,7] = 1
%     [1,8] = 3
%   }
%
%   [1,10] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 2
%     [1,5] = 1
%     [1,6] = 2
%   }
%
%   [1,11] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 3
%     [1,5] = 2
%     [1,6] = 3
%   }
%
%   [1,12] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 3
%     [1,5] = 1
%     [1,6] = 3
%   }
%
%   [1,13] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 2
%     [1,6] = 3
%     [1,7] = 1
%     [1,8] = 6
%   }
%
%   [1,14] =
%   {
%     [1,1] = 2
%     [1,2] = 1
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 1
%     [1,6] = 3
%     [1,7] = 1
%     [1,8] = 6
%   }
%
%   [1,15] =
%   {
%     [1,1] = 3
%     [1,2] = 1
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 2
%     [1,6] = 3
%     [1,7] = 1
%     [1,8] = 7
%   }
%
%   [1,16] =
%   {
%     [1,1] = 3
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 3
%     [1,5] = 1
%     [1,6] = 3
%     [1,7] = 1
%     [1,8] = 9
%   }
%
%   [1,17] =
%   {
%     [1,1] = 3
%     [1,2] = 2
%     [1,3] = 3
%     [1,4] = 3
%     [1,5] = 3
%     [1,6] = 4
%     [1,7] = 2
%     [1,8] = 8
%   }
%
%   [1,18] =
%   {
%     [1,1] = 6
%     [1,2] = 2
%     [1,3] = 4
%     [1,4] = 5
%     [1,5] = 3
%     [1,6] = 4
%     [1,7] = 3
%     [1,8] = 7
%     [1,9] = 2
%     [1,10] = 12
%   }
%
%   [1,19] =
%   {
%     [1,1] = 6
%     [1,2] = 2
%     [1,3] = 4
%     [1,4] = 5
%     [1,5] = 3
%     [1,6] = 4
%     [1,7] = 2
%     [1,8] = 5
%     [1,9] = 1
%     [1,10] = 4
%     [1,11] = 2
%     [1,12] = 4
%     [1,13] = 1
%     [1,14] = 3
%     [1,15] = 1
%     [1,16] = 3
%     [1,17] = 1
%     [1,18] = 13
%   }
%
%   [1,20] =
%   {
%     [1,1] = 5
%     [1,2] = 1
%     [1,3] = 4
%     [1,4] = 6
%     [1,5] = 2
%     [1,6] = 8
%     [1,7] = 1
%     [1,8] = 6
%     [1,9] = 1
%     [1,10] = 6
%     [1,11] = 1
%     [1,12] = 5
%     [1,13] = 1
%     [1,14] = 10
%   }
%
%   [1,21] =
%   {
%     [1,1] = 3
%     [1,2] = 1
%     [1,3] = 2
%     [1,4] = 6
%     [1,5] = 2
%     [1,6] = 7
%     [1,7] = 1
%     [1,8] = 9
%     [1,9] = 1
%     [1,10] = 7
%     [1,11] = 0
%     [1,12] = 14
%   }
%
%   [1,22] =
%   {
%     [1,1] = 2
%     [1,2] = 2
%     [1,3] = 1
%     [1,4] = 6
%     [1,5] = 1
%     [1,6] = 10
%     [1,7] = 1
%     [1,8] = 18
%   }
%
%   [1,23] =
%   {
%     [1,1] = 2
%     [1,2] = 2
%     [1,3] = 1
%     [1,4] = 6
%     [1,5] = 1
%     [1,6] = 4
%     [1,7] = 0
%     [1,8] = 10
%     [1,9] = 0
%     [1,10] = 9
%     [1,11] = 0
%     [1,12] = 19
%     [1,13] = 0
%     [1,14] = 15
%     [1,15] = 0
%     [1,16] = 18
%   }
%
%   [1,24] =
%   {
%     [1,1] = 2
%     [1,2] = 2
%     [1,3] = 1
%     [1,4] = 7
%     [1,5] = 1
%     [1,6] = 6
%     [1,7] = 0
%     [1,8] = 15
%     [1,9] = 0
%     [1,10] = 16
%     [1,11] = 0
%     [1,12] = 22
%   }
%
%   [1,25] =
%   {
%     [1,1] = 2
%     [1,2] = 3
%     [1,3] = 1
%     [1,4] = 6
%     [1,5] = 0
%     [1,6] = 8
%     [1,7] = 0
%     [1,8] = 8
%     [1,9] = 0
%     [1,10] = 9
%     [1,11] = 0
%     [1,12] = 6
%     [1,13] = 0
%     [1,14] = 6
%     [1,15] = 0
%     [1,16] = 22
%     [1,17] = 0
%     [1,18] = 15
%   }
%
%   [1,26] =
%   {
%     [1,1] = 2
%     [1,2] = 3
%     [1,3] = 1
%     [1,4] = 6
%     [1,5] = 0
%     [1,6] = 7
%     [1,7] = 0
%     [1,8] = 5
%     [1,9] = 0
%     [1,10] = 10
%     [1,11] = 0
%     [1,12] = 8
%     [1,13] = 0
%     [1,14] = 8
%     [1,15] = 0
%     [1,16] = 20
%     [1,17] = 0
%     [1,18] = 15
%   }
%
%   [1,27] =
%   {
%     [1,1] = 2
%     [1,2] = 3
%     [1,3] = 1
%     [1,4] = 5
%     [1,5] = 0
%     [1,6] = 9
%     [1,7] = 0
%     [1,8] = 6
%     [1,9] = 0
%     [1,10] = 10
%     [1,11] = 0
%     [1,12] = 8
%     [1,13] = 0
%     [1,14] = 6
%     [1,15] = 0
%     [1,16] = 17
%     [1,17] = 0
%     [1,18] = 12
%     [1,19] = 0
%     [1,20] = 10
%   }
%
%   [1,28] =
%   {
%     [1,1] = 3
%     [1,2] = 3
%     [1,3] = 0
%     [1,4] = 6
%     [1,5] = 0
%     [1,6] = 8
%     [1,7] = 0
%     [1,8] = 8
%     [1,9] = 0
%     [1,10] = 9
%     [1,11] = 0
%     [1,12] = 8
%     [1,13] = 0
%     [1,14] = 8
%     [1,15] = 0
%     [1,16] = 7
%     [1,17] = 0
%     [1,18] = 8
%     [1,19] = 0
%     [1,20] = 21
%     [1,21] = 0
%     [1,22] = 14
%   }
%
%   [1,29] =
%   {
%     [1,1] = 3
%     [1,2] = 3
%     [1,3] = 0
%     [1,4] = 5
%     [1,5] = 0
%     [1,6] = 9
%     [1,7] = 0
%     [1,8] = 6
%     [1,9] = 0
%     [1,10] = 9
%     [1,11] = 0
%     [1,12] = 6
%     [1,13] = 0
%     [1,14] = 8
%     [1,15] = 0
%     [1,16] = 6
%     [1,17] = 0
%     [1,18] = 8
%     [1,19] = 0
%     [1,20] = 6
%     [1,21] = 0
%     [1,22] = 24
%     [1,23] = 0
%     [1,24] = 19
%     [1,25] = 0
%     [1,26] = 31
%     [1,27] = 0
%     [1,28] = 29
%     [1,29] = 0
%     [1,30] = 19
%     [1,31] = 0
%     [1,32] = 20
%   }
%
%   [1,30] =
%   {
%     [1,1] = 3
%     [1,2] = 3
%     [1,3] = 0
%     [1,4] = 6
%     [1,5] = 0
%     [1,6] = 9
%     [1,7] = 0
%     [1,8] = 7
%     [1,9] = 0
%     [1,10] = 8
%     [1,11] = 0
%     [1,12] = 5
%     [1,13] = 0
%     [1,14] = 21
%     [1,15] = 0
%     [1,16] = 17
%     [1,17] = 0
%     [1,18] = 11
%     [1,19] = 0
%     [1,20] = 16
%     [1,21] = 0
%     [1,22] = 9
%     [1,23] = 0
%     [1,24] = 23
%     [1,25] = 0
%     [1,26] = 20
%     [1,27] = 0
%     [1,28] = 19
%   }
%
% }

% %% [markdown]
% ## 7) Postprocessing and Inline Visualization
%
% This cell reproduces the script visualization and shows figures directly in notebook output.

% %%
% Keep only boundary surface faces
v = elem(1:4,:);
F = [v([2 3 4],:), v([1 3 4],:), v([1 2 4],:), v([1 2 3],:)];
Fs = sort(F,1).';
[~,~,ic] = unique(Fs, 'rows');
cnt = accumarray(ic, 1);
bndFs = Fs(cnt(ic) == 1, :);

surfV = surf(1:3,:);
surfKs = sort(surfV,1).';
isBnd = ismember(surfKs, bndFs, 'rows');
surf = surf(:, isBnd);

if direct_on
    VIZ.draw_mesh_3D(coord, surf);
    VIZ.draw_quantity_3D_old(coord, surf, zeros(size(coord)), pw, x1, x2, x3, y1, y2, z);
    VIZ.plot_displacements_3D(U2, coord, elem, surf, 0.05 * max(abs(coord(:))) / max(abs(U2(:))));
    VIZ.plot_deviatoric_strain_3D(U2, coord, elem, surf, B);

    figure; hold on; box on; grid on;
    plot(omega_hist2, lambda_hist2, '-o');
    title('Direct continuation method', 'Interpreter', 'latex');
    xlabel('variable - $\\xi$', 'Interpreter', 'latex');
    ylabel('strength reduction factor - $\\lambda$', 'Interpreter', 'latex');
end

if indirect_on
    VIZ.draw_mesh_3D(coord, surf);
    drawnow; pause(0.2);

    VIZ.plot_pore_pressure_3D(pw, coord, surf);
    drawnow; pause(0.2);

    VIZ.plot_displacements_3D(U3, coord, elem, surf, 0.05 * max(abs(coord(:))) / max(abs(U3(:))));
    drawnow; pause(0.2);

    VIZ.plot_deviatoric_strain_3D(U3, coord, elem, surf, B);
    cl = caxis(gca);
    caxis([cl(1), 0.25 * cl(2)]);
    drawnow; pause(0.2);

    plane_vals = {[], [35], [1e-16, 21.6506]};
    [figs, info] = VIZ.plot_deviatoric_norm_slices(B, U3, elem, coord, Xi, surf, plane_vals, 1); %#ok<NASGU,ASGLU>

    figure; hold on; box on; grid on;
    plot(omega_hist3, lambda_hist3, '-o');
    title('Indirect continuation method', 'Interpreter', 'latex');
    xlabel('control variable - $\\omega$', 'Interpreter', 'latex');
    ylabel('strength reduction factor - $\\lambda$', 'Interpreter', 'latex');
end

drawnow;
fprintf('Notebook workflow completed.\\n');
% Out:
% warning: latex_renderer: unable to compile "control variable - $\\omega$"
% warning: called from
%     __axis_label__ at line 38 column 6
%     xlabel at line 59 column 3
%
% warning: latex_renderer: unable to compile "strength reduction factor - $\\lambda$"
% warning: called from
%     __axis_label__ at line 38 column 6
%     ylabel at line 61 column 3
%
% Notebook workflow completed.\n
